# %%
#%matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # Importando Librerias

# %%
import numpy as np
from matplotlib import pyplot  as pt

from mpl_toolkits import mplot3d

# %% [markdown]
# # Metodo que retorna los puntos de Lissajous

# %%
def Lissajous(lnm, m, v, p, h, tf):
    k = m * (lnm**2)
    a = -k * p / m
    ps = [ p ]
    for t in np.arange(0, tfin, h):
        a = -k * p / m
        v = v + a*h
        p  = p  + v*h
        ps.append(p)
    return ps

# %% [markdown]
# #  Con estos datos dibujar las figuras de Lissajous con las condiciones iniciales

# %% [markdown]
# (a) x = 1, vx = 0, y = +1, vy = 0

# %%
p = np.array([ 1, 1 ])
v = np.array([ 0, 0 ])

m = np.array([ 1, 1]) 
ln = np.array([ 1 , 1 ])
h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax.plot([p[0] for p in ps], [p[1] for p in ps])
ax.grid()
ax.set_aspect('equal')

# %% [markdown]
# (b) x = 1, vx = 0, y = −1, vy = 0

# %%
p = np.array([ 1, -1 ])
v = np.array([ 0, 0 ])

m = np.array([ 1, 1]) 
ln = np.array([ 1 , 1 ])
h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax.plot([p[0] for p in ps], [p[1] for p in ps])
ax.grid()
ax.set_aspect('equal')

# %% [markdown]
# (c) x = 1, vx = 0, y = +1, vy = 0.3

# %%
p = np.array([ 1, 1 ])
v = np.array([ 0, 0.3 ])

m = np.array([ 1, 1]) 
ln = np.array([ 1 , 1 ])
h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax.plot([p[0] for p in ps], [p[1] for p in ps])
ax.grid()
ax.set_aspect('equal')

# %% [markdown]
# (d) x = 1, vx = 0, y = −1, vy = 0.3

# %%
p = np.array([ 1, -1 ])
v = np.array([ 0, 0.3 ])

m = np.array([ 1, 1]) 
ln = np.array([ 1 , 1 ])
h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax.plot([p[0] for p in ps], [p[1] for p in ps])
ax.grid()
ax.set_aspect('equal')

# %% [markdown]
# (e) x = 1, vx = 0, y = 0, vy = 0.3

# %%
p = np.array([ 1, 0 ])
v = np.array([ 0, 0.3 ])

m = np.array([ 1, 1]) 
ln = np.array([ 1 , 1 ])
h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax.plot([p[0] for p in ps], [p[1] for p in ps])
ax.grid()
ax.set_aspect('equal')

# %% [markdown]
# #  Cada elemento de fila es (a), (b), (c), (d), (e). Fabrique para

# %% [markdown]
# (a) l = 1, n = 2

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 1 , 2 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# (b) l = 1, n = 3

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 1 , 3 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# (c) l = 2, n = 3

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 2 , 3 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# (d) l = 3, n = 4

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 3 , 4 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# (e) l = 3, n = 5

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 3 , 5 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# (f) l = 4, n = 5

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 4 , 5 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# (g) l = 5, n = 6

# %%
m = np.array([ 1, 1]) 
ln = np.array([ 5 , 6 ])

datos = [
    [ np.array([ 1, 1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0 ]) ],
    [ np.array([ 1, 1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, -1 ]), np.array([ 0, 0.3 ]) ],
    [ np.array([ 1, 0 ]), np.array([ 0, 0.3 ]) ]
]


h = 0.01
tfin=100

fig, ax = pt.subplots(1,5, constrained_layout=True)

for i, data in enumerate(datos):
    ps = Lissajous(ln, m,data[1],data[0],h, tfin)
    ax[i].plot([p[0] for p in ps], [p[1] for p in ps])
    ax[i].grid()
    ax[i].set_aspect('equal')
    ax[i].set(xlim=(-1,1), ylim=(-1,1))

# %% [markdown]
# # Con estos datos dibujar una figura de Lissajous con las condiciones iniciales en 3D como referencia.

# %% [markdown]
# (a) x = 1, vx = 0, z = 1, vz = 0, y = +1, vy = 0

# %%
p = np.array([ 1, 1, 1 ])
v = np.array([ 0, 0, 0 ])


m = np.array([ 1, 1 , 1]) 
ln = np.array([  1, 2 , 3  ])


h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax = pt.axes(projection='3d')
ax.plot([p[0] for p in ps], [p[1] for p in ps] ,[p[2] for p in ps])
ax.set(xlabel='X', ylabel='Y', zlabel='Z')
ax.grid()

# %% [markdown]
# (b) x = 1, vx = 0, z = 1, vz = 0, y = −1, vy = 0

# %%
p = np.array([ 1, -1, 1 ])
v = np.array([ 0, 0, 0 ])


m = np.array([ 1, 1 , 1]) 
ln = np.array([  1, 2 , 3  ])


h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax = pt.axes(projection='3d')
ax.plot([p[0] for p in ps], [p[1] for p in ps] ,[p[2] for p in ps])
ax.set(xlabel='X', ylabel='Y', zlabel='Z')
ax.grid()

# %% [markdown]
# (c) x = 1, vx = 0, z = 1, vz = 0, y = +1, vy = 0.3

# %%
p = np.array([ 1, 1, 1 ])
v = np.array([ 0, 0.3, 0 ])


m = np.array([ 1, 1 , 1]) 
ln = np.array([ 1, 2 , 3 ])


h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax = pt.axes(projection='3d')
ax.plot([p[0] for p in ps], [p[1] for p in ps] ,[p[2] for p in ps])
ax.set(xlabel='X', ylabel='Y', zlabel='Z')
ax.grid()

# %% [markdown]
# (d) x = 1, vx = 0, z = 1, vz = 0, y = −1, vy = 0.3

# %%
p = np.array([ 1, -1, 1 ])
v = np.array([ 0, 0.3, 0 ])


m = np.array([ 1, 1 , 1]) 
ln = np.array([  1, 2 , 3  ])


h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax = pt.axes(projection='3d')
ax.plot([p[0] for p in ps], [p[1] for p in ps] ,[p[2] for p in ps])
ax.set(xlabel='X', ylabel='Y', zlabel='Z')
ax.grid()

# %% [markdown]
# (e) x = 1, vx = 0, z = 1, vz = 0, y = 0, vy = 0.3

# %%
p = np.array([ 1, 0, 1 ])
v = np.array([ 0, 0.3, 0 ])


m = np.array([ 1, 1 , 1]) 
ln = np.array([  1, 2 , 3  ])


h = 0.01
tfin=100
ps = Lissajous(ln, m,v,p,h, tfin)
fig, ax = pt.subplots()
ax = pt.axes(projection='3d')
ax.plot([p[0] for p in ps], [p[1] for p in ps] ,[p[2] for p in ps])
ax.set(xlabel='X', ylabel='Y', zlabel='Z')
ax.grid()
