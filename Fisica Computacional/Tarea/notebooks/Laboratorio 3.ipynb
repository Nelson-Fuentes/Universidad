# %%
#matplotlib notebook
matplotlib inline
# Out:
#   File "<ipython-input-1-6dd8ab01e6da>", line 2
#     matplotlib inline
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Importando Librerias

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import sys
import random

# %% [markdown]
# # Importando Modelos

# %%
from models.Graphic import Graphic, Graphic3D
from models.Vector import Vector, Coordenate

# %% [markdown]
# # Constantes

# %%
MAX_INT = 100
MIN_INT = -MAX_INT

# %% [markdown]
# # Metodos

# %% [markdown]
# ## Obtener Signo

# %%
def getSigno(x):
    if x == 0:
        return 0
    return x/abs(x)

# %% [markdown]
# ## Graficar Vector 2D

# %%
def vector2D(axis, vector):
    axis.quiver(vector.origin.x, vector.origin.y,  vector.x,vector.y , angles='xy', scale_units='xy', scale=1)

# %% [markdown]
# ## Graficar Punto 2D

# %%
def point2D(axis, coordenate):
    axis.plot(coordenate.x, coordenate.y, marker="o", )

# %% [markdown]
# # a = cte

# %% [markdown]
# ## Movimiento en una dimensión. Caída libre g = −10 m/s2

# %% [markdown]
# ### Sea una partícula, que tiene una posición inicial y◦ y velocidad inicial vy◦ en un tiempo inicial t = 0. Determine la posición final de la partíicula para t = 10 s con g = −10 m/s2. Haga los diagramas a − t, v − t, x − t y v − x y por cada caso de un ejemplo real. Considere h = 0.1

# %% [markdown]
# ####  y◦ < 0, vy◦ < 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-52
# Velocidad Inicial	:	-62
# Tiempo Final		:	10
# Posicion FInal		:	-1177.0000000000002

# %% [markdown]
# #### y◦ < 0, vy◦ = 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=0))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-95
# Velocidad Inicial	:	0
# Tiempo Final		:	10
# Posicion FInal		:	-600.0

# %% [markdown]
# #### y◦ < 0, vy◦ > 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-18
# Velocidad Inicial	:	66
# Tiempo Final		:	10
# Posicion FInal		:	137.0

# %% [markdown]
# #### y◦ = 0, vy◦ < 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	0
# Velocidad Inicial	:	-20
# Tiempo Final		:	10
# Posicion FInal		:	-705.0

# %% [markdown]
# ### y◦ = 0, vy◦ = 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=0,y=0))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	0
# Velocidad Inicial	:	0
# Tiempo Final		:	10
# Posicion FInal		:	-505.0

# %% [markdown]
# #### y◦ = 0, vy◦ > 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	0
# Velocidad Inicial	:	75
# Tiempo Final		:	10
# Posicion FInal		:	245.0

# %% [markdown]
# #### y◦ > 0, vy◦ < 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	94
# Velocidad Inicial	:	-21
# Tiempo Final		:	10
# Posicion FInal		:	-621.0

# %% [markdown]
# #### y◦ > 0, vy◦ = 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))   
v0 = Vector(value=Coordenate(x=0,y=0))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	32
# Velocidad Inicial	:	0
# Tiempo Final		:	10
# Posicion FInal		:	-473.0

# %% [markdown]
# #### y◦ > 0, vy◦ > 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))  


tf = 10                                 
h = 0.1
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	35
# Velocidad Inicial	:	25
# Tiempo Final		:	10
# Posicion FInal		:	-220.00000000000003

# %% [markdown]
# ### Una partícula se mueve, en el eje x con aceleración ax = 10 m/s2, hasta una posición final xf y velocidad final vxf que lo hace en un tiempo tf = 20 s. Encuentre la posición inicial x◦ y la vy◦. Haga los diagramas a − t, v − t, x − t y v − x y por cada caso de un ejemplo real. Considere h = 0.05

# %% [markdown]
# #### xf < 0, vxf < 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))  


tf = 20                                 
h = 0.05
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 - a.mulEscalar(h)
    yf = yf - v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-26
# Velocidad Inicial	:	-5
# Tiempo Final		:	20
# Posicion FInal		:	2079.0

# %% [markdown]
# #### xf < 0, vxf = 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=0))  


tf = 20                                 
h = 0.05
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 - a.mulEscalar(h)
    yf = yf - v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-94
# Velocidad Inicial	:	0
# Tiempo Final		:	20
# Posicion FInal		:	1911.0

# %% [markdown]
# #### xf < 0, vxf > 0

# %%
fig, axis = plt.subplots(2 , 2, constrained_layout=True) # Esquema
a = Vector(value=Coordenate(x=1, y=10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))  


tf = 20                                 
h = 0.05
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 - a.mulEscalar(h)
    yf = yf - v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

axis[0][0].plot(t, as_)
axis[0][0].grid()
axis[0][0].set(ylabel = 'Aceleración', xlabel='Tiempo')


axis[1][1].plot(t,vy)
axis[1][1].set(ylabel = 'Velocidad', xlabel='Tiempo')
axis[1][1].grid()

axis[1][0].plot(t, dy)
axis[1][0].set(ylabel = 'Desplazamiento', xlabel='Tiempo')
axis[1][0].grid()

axis[0][1].plot(dy, vy)
axis[0][1].grid()
axis[0][1].set(ylabel = 'Velocidad', xlabel='Desplazamiento')

print("Posicion FInal\t\t:\t{}".format(yf.y))
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-46
# Velocidad Inicial	:	10
# Tiempo Final		:	20
# Posicion FInal		:	1758.9999999999998

# %% [markdown]
# ### Una partícula se mueve, en el eje x con aceleración ax = 10 m/s2, desde una posición inicial xi y velocidad inicial vxi que lo hace en un tiempo ti = 14 s. Encuentre la posición final xf y la vf. Haga el diagrama v − x − t. Considere h = 0.01

# %% [markdown]
# ####  xi > 0, vxi < 0

# %%
a = Vector(value=Coordenate(x=1, y=10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(MIN_INT, 0)))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))  


tf = 14                                 
h = 0.01
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

print("Posicion FInal\t\t:\t{}\nVelocidad Final\t:\t{}".format(yf.y, v0.y))
fig = plt.figure()
ax3d = plt.axes(projection='3d')
ax3d.plot(t, vy, dy)
ax3d.set(xlabel='Tiempo', ylabel='Velocidad', zlabel='Desplazamiento')
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	-75
# Velocidad Inicial	:	98
# Tiempo Final		:	14
# Posicion FInal		:	2277.699999999945
# Velocidad Final	:	237.99999999999204
# [Text(0.5, 0, 'Desplazamiento'),
#  Text(0.5, 0, 'Velocidad'),
#  Text(0.5, 0, 'Tiempo')]

# %% [markdown]
# #### xi < 0, vxi = 0

# %%
a = Vector(value=Coordenate(x=1, y=10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))   
v0 = Vector(value=Coordenate(x=0,y=0))  


tf = 14                                 
h = 0.01
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

print("Posicion FInal\t\t:\t{}\nVelocidad Final\t:\t{}".format(yf.y, v0.y))
fig = plt.figure()
ax3d = plt.axes(projection='3d')
ax3d.plot(t, vy, dy)
ax3d.set(xlabel='Tiempo', ylabel='Velocidad', zlabel='Desplazamiento')
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	25
# Velocidad Inicial	:	0
# Tiempo Final		:	14
# Posicion FInal		:	1005.6999999999897
# Velocidad Final	:	139.99999999999633
# [Text(0.5, 0, 'Desplazamiento'),
#  Text(0.5, 0, 'Velocidad'),
#  Text(0.5, 0, 'Tiempo')]

# %% [markdown]
# #### xi = 0, vxi > 0

# %%
a = Vector(value=Coordenate(x=1, y=10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=0,y=random.randint(0, MAX_INT)))  


tf = 14                                 
h = 0.01
yf = y0

print("Tiempo inicial\t\t:\t{}\nPunto Inicial\t\t:\t{}\nVelocidad Inicial\t:\t{}\nTiempo Final\t\t:\t{}".format(t0, y0.y, v0.y, tf))


t = [ 0 ]
vy = [ v0.y ]
dy = [ y0.y ]
as_ = [ a.y ] 

for i in np.arange(0,tf,h):
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t.append(i+h)
    vy.append(v0.y)
    dy.append(yf.y)
    as_.append(a.y)
 

print("Posicion FInal\t\t:\t{}\nVelocidad Inicial\t:\t{}".format(yf.y, v0.y))
fig = plt.figure()
ax3d = plt.axes(projection='3d')
ax3d.plot(t, vy, dy)
ax3d.set(xlabel='Tiempo', ylabel='Velocidad', zlabel='Desplazamiento')
# Out:
# Tiempo inicial		:	0
# Punto Inicial		:	0
# Velocidad Inicial	:	9
# Tiempo Final		:	14
# Posicion FInal		:	1106.6999999999862
# Velocidad Inicial	:	148.99999999999582
# [Text(0.5, 0, 'Desplazamiento'),
#  Text(0.5, 0, 'Velocidad'),
#  Text(0.5, 0, 'Tiempo')]

# %% [markdown]
# ## Movimiento en 2D y 3D con aceleración constante en la dirección y

# %% [markdown]
# ### Una partícula parte del reposo r = 0 m con una velocidad inicial vi = (2i + 3j) m/s. grafique su trayectoria hasta que la partícula cruce el eje x. De un ejemplo real.

# %%
a = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=2,y=3))  


tf = 0.5                               
h = 0.001

yf = y0


xs = [ y0.x ]
ys = [ y0.y ] 

while yf.y >= 0:
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    ys.append(yf.y)
    xs.append(yf.x)

print("Posicion Final\t\t:\t({}, {})\nVelocidad Final\t\t:\t({},{})".format(yf.x,yf.y, v0.x, v0.y))
fig = plt.figure()
ax = plt.axes()
ax.plot(xs, ys)
ax.set(xlabel='X', ylabel='Y')
ax.grid()
# Out:
# Posicion Final		:	(1.2000000000000008, -0.0029999999999882157)
# Velocidad Final		:	(2.0,-2.9999999999999605)

# %% [markdown]
# ### Una partícula parte del reposo r = (3i + 4k) m con una velocidad inicial v = (2i + 3j − 4k) m/s. Dibuje la trayectoria hasta que la partícula cruce el plano xz.

# %%
a = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=3,y=4))   
v0 = Vector(value=Coordenate(x=2,y=3, z = -4))  


tf = 0.5                               
h = 0.001

yf = y0


xs = [ y0.x ]
ys = [ y0.y ] 
zs = [ y0.z ]
while yf.y >= 0:
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    ys.append(yf.y)
    xs.append(yf.x)
    zs.append(yf.z)

print("Posicion Final\t\t:\t{}\nVelocidad Final\t\t:\t{}".format(yf.y, v0.y))
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(xs, zs, ys)
ax.set(xlabel='X', ylabel='Z', zlabel='Y')
ax.grid()
# Out:
# Posicion Final		:	-0.002459999999920963
# Velocidad Final		:	-9.429999999999824

# %% [markdown]
# ###  Una pelota se lanza desde el techo r = (4i + 3j) m con una velocidad inicial vi = (2i + 3j − 4k)m/s.
#
#     (a) Dibuje la trayectoria hasta que la partícula llegue al suelo.
#     (b) Determine el tiempo en que la pelota llega a una altura máxima
#     (c) En ese tiempo ubique las coordenadas de la pelota.
#     (d) Determine el alcance vectorialmente.

# %%
a = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=4,y=3))   
v0 = Vector(value=Coordenate(x=2,y=3, z = -4))  


tf = 0.5                               
h = 0.0009

yf = y0
lv = v0

xs = [ y0.x ]
ys = [ y0.y ] 
zs = [ y0.z ]
while yf.y >= 0:
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t0 = t0 + h
    
    ys.append(yf.y)
    xs.append(yf.x)
    zs.append(yf.z)
    
    if v0.y == 0 or getSigno(v0.y)!=getSigno(lv.y):
        print ("Tiempo de la cima\t:\t{:.2f}\nCima en\t\t\t:\t({:.2f}, {:.2f}, {:.2f})".format(t0,yf.x,yf.y,yf.z))
    lv = v0
    
    

print("Alcance\t\t\t:\t({:.2f}, {:.2f}, {:.2f})".format(yf.x, yf.y,yf.z))
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(xs, zs, ys)
ax.set(xlabel='X', ylabel='Z', zlabel='Y')
ax.grid()
# Out:
# Tiempo de la cima	:	0.30
# Cima en			:	(4.60, 3.45, -1.20)
# Alcance			:	(6.26, -0.00, -4.52)

# %% [markdown]
# ## Movimiento en 2D y 3D con aceleración constante en dos direcciones

# %% [markdown]
# ### Una partícula parte del reposo desde r = (3i) m con una velocidad v = −2i m/s. Hay una ráfaga de viento cuya velocidad es vv = (4k) m/s. Determine la trayectoria de la partícula cuando llegue al suelo

# %%
a = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=3))   
v0 = Vector(value=Coordenate(x=-2))   +  Vector(value=Coordenate(z = 4))  


tf = 0.5                               
h = 0.0009

yf = y0
lv = v0

xs = [ y0.x ]
ys = [ y0.y ] 
zs = [ y0.z ]
while yf.y >= 0:
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t0 = t0 + h
    
    ys.append(yf.y)
    xs.append(yf.x)
    zs.append(yf.z)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f}, {:.2f})".format(yf.x, yf.y,yf.z))
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(xs, zs, ys)
ax.set(xlabel='X', ylabel='Z', zlabel='Y')
ax.grid()
# Out:
# Alcance			:	(3.00, -0.00, 0.00)

# %% [markdown]
# ### Una pelota se ubica en el techo de un edificio cuyas ubicación es r = (10i+ 10j + 10k)m. Luego un niño patea dicha pelota con la velocidad vp = 2i m/s. Pero se encuentra con la sorpresa que hay un viento cuya velocidad es vw = (−2i + 4k) m/s. Determine la trayectoria de la pelota hasta que llegue al suelo.

# %%
a = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=10,y=10, z = 10))   
v0 = Vector(value=Coordenate(x=2))   +  Vector(value=Coordenate(x = -2, z = 4))  


tf = 0.5                               
h = 0.001

yf = y0
lv = v0

xs = [ y0.x ]
ys = [ y0.y ] 
zs = [ y0.z ]
while yf.y >= 0:
    v0 = v0 + a.mulEscalar(h)
    yf = yf + v0.mulEscalar(h)
    t0 = t0 + h
    
    ys.append(yf.y)
    xs.append(yf.x)
    zs.append(yf.z)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f}, {:.2f})".format(yf.x, yf.y,yf.z))
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(xs, zs, ys)
ax.set(xlabel='X', ylabel='Z', zlabel='Y')
ax.grid()
# Out:
# Alcance			:	(10.00, -0.00, 15.66)

# %% [markdown]
# ### La ecuaciones de la cinemática de un movimiento parabólico cuando una partícula parte de (0, 0) son x = vxit, y y = vyit + gt2/2 (vxi = 1 m/s, vyi = 1 m/s y g = −10 m/s2 ) . Se presenta una ráfaga de viento cuyas ecuación es xw = vwit + awt 2/2 (vwi = 2 m/s y aw = −1 m/s2 ). Utilice lapiz y papel para encontrar la ecuación de la trayectoria

# %%
a0 = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=1, y=1))

vw = Vector(value=Coordenate(x=2))
aw = Vector(value=Coordenate(x=-1))

v = v0 + vw
a = a0 + aw

tf = 0.5                               
h = 0.001

yf = y0
lv = v0

xs = [ y0.x ]
ys = [ y0.y ] 
while yf.y >= 0:
    v = v + a.mulEscalar(h)
    yf = yf  + v.mulEscalar(h)
    t0 = t0 + h
    ys.append(yf.y)
    xs.append(yf.x)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f})".format(yf.x, yf.y))
fig = plt.figure()
ax = plt.axes()
ax.plot(xs,ys)
ax.set(xlabel='X', ylabel='Y')
ax.grid()
# Out:
# Alcance			:	(0.58, -0.00)

# %% [markdown]
# ### Un jugador de Golf golpea una bola con el driver ubicado en r = 0. La bola sale con velocidad inicial v = (5i+2j) m/s. Pero resulta que esta presente una ráfaga de viento con una aceleración aw. Dibuje la trayectoria de la bola hasta que llegue al suelo y dibuje la posición final, cuando

# %%
a0 = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=5, y=2))

# %% [markdown]
# #### (a) aw = +2i m/s2, con vwi = 0

# %%
vw = Vector(value=Coordenate(x=0))
aw = Vector(value=Coordenate(x=2))

v = v0 + vw
a = a0 + aw
                            
h = 0.001

yf = y0

xs = [ y0.x ]
ys = [ y0.y ] 
while yf.y >= 0:
    v = v + a.mulEscalar(h)
    yf = yf  + v.mulEscalar(h)
    t0 = t0 + h
    ys.append(yf.y)
    xs.append(yf.x)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f})".format(yf.x, yf.y))
fig = plt.figure()
ax = plt.axes()
ax.plot(xs,ys)
ax.set(xlabel='X', ylabel='Y')
ax.grid()
# Out:
# Alcance			:	(2.15, -0.00)

# %% [markdown]
# #### (b) aw = −2i m/s2, con vwi = 0

# %%
vw = Vector(value=Coordenate(x=0))
aw = Vector(value=Coordenate(x=-2))

v = v0 + vw
a = a0 + aw
                            
h = 0.001

yf = y0

xs = [ y0.x ]
ys = [ y0.y ] 
while yf.y >= 0:
    v = v + a.mulEscalar(h)
    yf = yf  + v.mulEscalar(h)
    t0 = t0 + h
    ys.append(yf.y)
    xs.append(yf.x)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f})".format(yf.x, yf.y))
fig = plt.figure()
ax = plt.axes()
ax.plot(xs,ys)
ax.set(xlabel='X', ylabel='Y')
ax.grid()
# Out:
# Alcance			:	(1.84, -0.00)

# %% [markdown]
# #### (c) aw = (+2i + k) m/s2, con vwi = 0

# %%
a0 = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=5, y=2))

vw = Vector(value=Coordenate(x=0))
aw = Vector(value=Coordenate(x=2, z=1))

v = v0 + vw
a = a0 + aw
                            
h = 0.001

yf = y0

xs = [ y0.x ]
ys = [ y0.y ] 
zs = [ y0.z ]
while yf.y >= 0:
    v = v + a.mulEscalar(h)
    yf = yf  + v.mulEscalar(h)
    t0 = t0 + h
    ys.append(yf.y)
    xs.append(yf.x)
    zs.append(yf.z)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f}, {:.2f})".format(yf.x, yf.y, yf.z))
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.plot(xs,zs,ys)
ax.set(xlabel='X', ylabel = 'Z', zlabel='Y')
ax.grid()
# Out:
# Alcance			:	(2.15, -0.00, 0.08)

# %% [markdown]
# #### (d) aw = (+2i − k) m/s2, con vwi = 0

# %%
a0 = Vector(value=Coordenate(x=0, y=-10)) 

t0 = 0                              
y0 = Vector(value=Coordenate(x=0,y=0))   
v0 = Vector(value=Coordenate(x=5, y=2))


vw = Vector(value=Coordenate(x=0))
aw = Vector(value=Coordenate(x=2, z=-1))

v = v0 + vw
a = a0 + aw
                            
h = 0.001

yf = y0

xs = [ y0.x ]
ys = [ y0.y ] 
zs = [ y0.z ]
while yf.y >= 0:
    v = v + a.mulEscalar(h)
    yf = yf  + v.mulEscalar(h)
    t0 = t0 + h
    ys.append(yf.y)
    xs.append(yf.x)
    zs.append(yf.z)

    

print("Alcance\t\t\t:\t({:.2f}, {:.2f}, {:.2f})".format(yf.x, yf.y, yf.z))
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.plot(xs,zs,ys)
ax.set(xlabel='X', ylabel = 'Z', zlabel='Y')
ax.grid()
# Out:
# Alcance			:	(2.15, -0.00, -0.08)
